# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image= cv2.imread('Aadhaar-card.png')
plt.imshow(image)
plt.show()

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text=pytesseract.image_to_string(image)

# %%
print(text)
# Out:
# Name XXxx
# DOB: XXXX-XXXX
# Gender: MALE
#
#
#
# 0000 1111 2222
# Sere - ara srregatt at Sefer

# %%
res=text.split()

# %%
res
# Out:
# ['Name',
#  'XXxx',
#  'DOB:',
#  'XXXX-XXXX',
#  'Gender:',
#  'MALE',
#  '0000',
#  '1111',
#  '2222',
#  'Sere',
#  '-',
#  'ara',
#  'srregatt',
#  'at',
#  'Sefer']

# %%
index =res.index('Gender:')

# %%
uid= res[index+2] + ' ' + res[index+3] + ' ' + res[index+4]

# %%
uid
# Out:
# '0000 1111 2222'
